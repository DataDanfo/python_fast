# %% [markdown]
# # Python Big Four
# 1. for
# 2. list
# 3. Dictionary
# 4. Conditions

# %% [markdown]
# - strings are colletion of characters
# - name is variable because it holds a value

# %%
name = "Eric"
x = 5  # this is an
# integer
y = 6.7 # this float
z = 34j  # this is complex
print(name, x, y , z)
# Out:
# Eric 5 6.7 34j

# %%
type(z), type(y), type(name)
# Out:
# (complex, float, str)

# %%
fruits = ["apple", "bannana", "Pizza"]

# %%
fruits[-3]
# Out:
# 'apple'

# %%
print(fruits)
# Out:
# ['apple', 'bannana', 'Pizza']

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[1]
# Out:
# 'bannana'

# %%
fruits[2]
# Out:
# 'Pizza'

# %%
# for

# %%
fruits = ["apple", "bannana", "Pizza"]

# %%
for item in fruits:
    print(item)
# Out:
# apple
# bannana
# Pizza

# %%
numx = [1,2,3]

# %%
sum = 0
for num in numx:
    sum = sum + num

# %%
sum
# Out:
# 6

# %%
# Tuesday  | ****  8pm - 10pm

# Thursday | ****  8pm -  9pm
