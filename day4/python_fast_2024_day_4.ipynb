# %%
bill_items = [
    ['Tom', 'Calamari', 6.00],
    ['Tom', 'American Hot', 11.50],
    ['Tom', 'Chocolate Fudge Cake', 4.45],
    ['Clare', 'Bruschetta Originale', 5.35],
    ['Clare', 'Fiorentina', 10.65],
    ['Clare', 'Tiramasu', 4.90],
    ['Rich', 'Bruschetta Originale', 5.35],
    ['Rich', 'La Reine', 10.65],
    ['Rich', 'Honeycomb Cream Slice', 4.90],
    ['Rosie', 'Garlic Bread', 4.35],
    ['Rosie', 'Veneziana', 9.40],
    ['Rosie', 'Tiramasu', 4.90],
]

# %%
a = [1,45,3,56,6,7]
b = ['bob','rana', 'panam', 'percy']

# %%
# Sort
a.sort()
print(a)
b.sort()
print(b)
# Out:
# [1, 3, 6, 7, 45, 56]
# ['bob', 'panam', 'percy', 'rana']

# %%
a = [1,45,3,56,6,7]
b = ['katalonama','ranatula', 'panam', 'percy']

# %%
def s(x):
    return len(x)

# %%
b.sort(key=s, reverse=True)

# %%
b
# Out:
# ['katalonama', 'ranatula', 'panam', 'percy']

# %%
s("helo")
# Out:
# 4

# %%
a.sort(reverse=True)
print(a)
# Out:
# [56, 45, 7, 6, 3, 1]

# %%
number = 5
answer = number * number
print(answer)
# Out:
# 25

# %%
number = 15
answer = number * number
print(answer)
# Out:
# 225

# %%
def square(number):
    answer = number * number
    return answer

# %%
square(2)
# Out:
# 4

# %%
square(4)
# Out:
# 16

# %%
square(7)
# Out:
# 49

# %%
# append

# %%
c = []
c.append(1)
c.append(2)
print(c)
# Out:
# [1, 2]

# %%
# clear
c.clear()
print(c)
# Out:
# []

# %%
# copy
a = [1,45,3,56,6,7]
b = ['bob','rana', 'panam', 'percy']

# %%
d = a.copy()
d
# Out:
# [56, 45, 7, 6, 3, 1]

# %%
d[0]=1

# %%
d
# Out:
# [1, 45, 7, 6, 3, 1]

# %%
a
# Out:
# [56, 45, 7, 6, 3, 1]

# %%
# count
e = [1,1,2,3]
e.count(2) # how many times I occurs
# Out:
# 1

# %%
# extend
f = [3,4]
g = [1,2]
f.extend(g)
print(f)
#[3, 4, 1, 2]
# Out:
# [3, 4, 1, 2]

# %%
# index
h = [1,2,3,6]
h.index(1)
# Out:
# 0

# %%
j = [1,2,3]
j.insert(0, 5)
j.insert(1, 6)

# %%
print(j)
# Out:
# [5, 6, 1, 2, 3]

# %%
# pop

j = [1,2,3]
r = j.pop()
print(r)
print(j)
# Out:
# 3
# [1, 2]

# %%
j = [1,2,3]
r = j.pop(0)
print(r)
print(j)
# Out:
# 1
# [2, 3]

# %%
# remove

j = [1,2,3,1]
j.remove(1)
print(j)
# Out:
# [2, 3, 1]

# %%
# remove

j = [1,2,3,1]
j.remove(2)
print(j)
# Out:
# [1, 3, 1]

# %%
j = [1,2,3,1]
j.reverse()

# %%
j
# Out:
# [1, 3, 2, 1]

# %%
j = [1,2,3,1]
j.sort()
j
# Out:
# [1, 1, 2, 3]

# %%
j = [1,2,3,1]
j.sort(reverse=True)
j
# Out:
# [3, 2, 1, 1]

# %%
https://www.w3schools.com/python/python_lists_methods.asp
